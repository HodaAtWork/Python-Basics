# %% [markdown]
# # File IO
# There is no programming language not offering some kind of file I/O. Python enables us to open, read, write both text and binary files. The notebook shows the basics; more can be found in Python documentation.

# %% [markdown]
# ## Reading text files

# %%
# FILE I/O
#
f = open('data/alices_adventures_in_wonderland.txt', mode = 'rt', encoding = 'utf-8')
for line in f:
    print('I Line is: {}'.format(line))
f.close()
#
# Identical:
#
f = open('data/alices_adventures_in_wonderland.txt', 'rt', encoding = 'utf-8')
for line in f:
    print('II Line is: {}'.format(line))
f.close()
#
# Identical:
# Enter your absolute path in statement below
absolute_path = 'C:\DATA'
f = open(absolute_path+'\\alices_adventures_in_wonderland.txt', encoding = 'utf-8')
for line in f:
    print('III Line is: {}'.format(line))
f.close()
#
# Identical:
#
f = open(absolute_path+'\\alices_adventures_in_wonderland.txt')
for line in f:
    print('IV Line is: {}'.format(line))
f.close()
#
# Identical (safe way):
#
try:
    f = open(absolute_path+'\\alices_adventures_in_wonderland.txt')
    print('Type f is: {}'.format(type(f)))
    for line in f:
        print('V Line is: {}'.format(line))
finally:
    f.close()
# Out:
# I Line is: ﻿Title: Alice's Adventures in Wonderland
#
# I Line is:
#
# I Line is: Author: Lewis Carroll
#
# I Line is:
#
# I Line is: Posting Date: June 25, 2008 [EBook #11]
#
# I Line is: Release Date: March, 1994
#
# I Line is: [Last updated: December 20, 2011]
#
# I Line is:
#
# I Line is: Language: English
#
# I Line is:
#
# I Line is:
#
# I Line is: CHAPTER I. Down the Rabbit-Hole
#
# I Line is:
#
# I Line is: Alice was beginning to get very tired of sitting by her sister on the
#
# I Line is: bank, and of having nothing to do: once or twice she had peeped into the
#
# I Line is: book her sister was reading, but it had no pictures or conversations in
#
# I Line is: it, 'and what is the use of a book,' thought Alice 'without pictures or
#
# I Line is: conversations?'
#
# I Line is:
#
# I Line is: So she was considering in her own mind (as well as she could, for the
#
# I Line is: hot day made her feel very sleepy and stupid), whether the pleasure
#
# I Line is: of making a daisy-chain would be worth the trouble of getting up and
#
# I Line is: picking the daisies, when suddenly a White Rabbit with pink eyes ran
#
# I Line is: close by her.
#
# I Line is:
#
# I Line is: There was nothing so VERY remarkable in that; nor did Alice think it so
#
# I Line is: VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
#
# I Line is: Oh dear! I shall be late!' (when she thought it over afterwards, it
#
# I Line is: occurred to her that she ought to have wondered at this, but at the time
#
# I Line is: it all seemed quite natural); but when the Rabbit actually TOOK A WATCH
#
# I Line is: OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,
#
# I Line is: Alice started to her feet, for it flashed across her mind that she had
#
# I Line is: never before seen a rabbit with either a waistcoat-pocket, or a watch
#
# I Line is: to take out of it, and burning with curiosity, she ran across the field
#
# I Line is: after it, and fortunately was just in time to see it pop down a large
#
# I Line is: rabbit-hole under the hedge.
# II Line is: ﻿Title: Alice's Adventures in Wonderland
#
# II Line is:
#
# II Line is: Author: Lewis Carroll
#
# II Line is:
#
# II Line is: Posting Date: June 25, 2008 [EBook #11]
#
# II Line is: Release Date: March, 1994
#
# II Line is: [Last updated: December 20, 2011]
#
# II Line is:
#
# II Line is: Language: English
#
# II Line is:
#
# II Line is:
#
# II Line is: CHAPTER I. Down the Rabbit-Hole
#
# II Line is:
#
# II Line is: Alice was beginning to get very tired of sitting by her sister on the
#
# II Line is: bank, and of having nothing to do: once or twice she had peeped into the
#
# II Line is: book her sister was reading, but it had no pictures or conversations in
#
# II Line is: it, 'and what is the use of a book,' thought Alice 'without pictures or
#
# II Line is: conversations?'
#
# II Line is:
#
# II Line is: So she was considering in her own mind (as well as she could, for the
#
# II Line is: hot day made her feel very sleepy and stupid), whether the pleasure
#
# II Line is: of making a daisy-chain would be worth the trouble of getting up and
#
# II Line is: picking the daisies, when suddenly a White Rabbit with pink eyes ran
#
# II Line is: close by her.
#
# II Line is:
#
# II Line is: There was nothing so VERY remarkable in that; nor did Alice think it so
#
# II Line is: VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
#
# II Line is: Oh dear! I shall be late!' (when she thought it over afterwards, it
#
# II Line is: occurred to her that she ought to have wondered at this, but at the time
#
# II Line is: it all seemed quite natural); but when the Rabbit actually TOOK A WATCH
#
# II Line is: OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,
#
# II Line is: Alice started to her feet, for it flashed across her mind that she had
#
# II Line is: never before seen a rabbit with either a waistcoat-pocket, or a watch
#
# II Line is: to take out of it, and burning with curiosity, she ran across the field
#
# II Line is: after it, and fortunately was just in time to see it pop down a large
#
# II Line is: rabbit-hole under the hedge.
# III Line is: ﻿Title: Alice's Adventures in Wonderland
#
# III Line is:
#
# III Line is: Author: Lewis Carroll
#
# III Line is:
#
# III Line is: Posting Date: June 25, 2008 [EBook #11]
#
# III Line is: Release Date: March, 1994
#
# III Line is: [Last updated: December 20, 2011]
#
# III Line is:
#
# III Line is: Language: English
#
# III Line is:
#
# III Line is:
#
# III Line is: CHAPTER I. Down the Rabbit-Hole
#
# III Line is:
#
# III Line is: Alice was beginning to get very tired of sitting by her sister on the
#
# III Line is: bank, and of having nothing to do: once or twice she had peeped into the
#
# III Line is: book her sister was reading, but it had no pictures or conversations in
#
# III Line is: it, 'and what is the use of a book,' thought Alice 'without pictures or
#
# III Line is: conversations?'
#
# III Line is:
#
# III Line is: So she was considering in her own mind (as well as she could, for the
#
# III Line is: hot day made her feel very sleepy and stupid), whether the pleasure
#
# III Line is: of making a daisy-chain would be worth the trouble of getting up and
#
# III Line is: picking the daisies, when suddenly a White Rabbit with pink eyes ran
#
# III Line is: close by her.
#
# III Line is:
#
# III Line is: There was nothing so VERY remarkable in that; nor did Alice think it so
#
# III Line is: VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
#
# III Line is: Oh dear! I shall be late!' (when she thought it over afterwards, it
#
# III Line is: occurred to her that she ought to have wondered at this, but at the time
#
# III Line is: it all seemed quite natural); but when the Rabbit actually TOOK A WATCH
#
# III Line is: OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,
#
# III Line is: Alice started to her feet, for it flashed across her mind that she had
#
# III Line is: never before seen a rabbit with either a waistcoat-pocket, or a watch
#
# III Line is: to take out of it, and burning with curiosity, she ran across the field
#
# III Line is: after it, and fortunately was just in time to see it pop down a large
#
# III Line is: rabbit-hole under the hedge.
# IV Line is: ï»¿Title: Alice's Adventures in Wonderland
#
# IV Line is:
#
# IV Line is: Author: Lewis Carroll
#
# IV Line is:
#
# IV Line is: Posting Date: June 25, 2008 [EBook #11]
#
# IV Line is: Release Date: March, 1994
#
# IV Line is: [Last updated: December 20, 2011]
#
# IV Line is:
#
# IV Line is: Language: English
#
# IV Line is:
#
# IV Line is:
#
# IV Line is: CHAPTER I. Down the Rabbit-Hole
#
# IV Line is:
#
# IV Line is: Alice was beginning to get very tired of sitting by her sister on the
#
# IV Line is: bank, and of having nothing to do: once or twice she had peeped into the
#
# IV Line is: book her sister was reading, but it had no pictures or conversations in
#
# IV Line is: it, 'and what is the use of a book,' thought Alice 'without pictures or
#
# IV Line is: conversations?'
#
# IV Line is:
#
# IV Line is: So she was considering in her own mind (as well as she could, for the
#
# IV Line is: hot day made her feel very sleepy and stupid), whether the pleasure
#
# IV Line is: of making a daisy-chain would be worth the trouble of getting up and
#
# IV Line is: picking the daisies, when suddenly a White Rabbit with pink eyes ran
#
# IV Line is: close by her.
#
# IV Line is:
#
# IV Line is: There was nothing so VERY remarkable in that; nor did Alice think it so
#
# IV Line is: VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
#
# IV Line is: Oh dear! I shall be late!' (when she thought it over afterwards, it
#
# IV Line is: occurred to her that she ought to have wondered at this, but at the time
#
# IV Line is: it all seemed quite natural); but when the Rabbit actually TOOK A WATCH
#
# IV Line is: OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,
#
# IV Line is: Alice started to her feet, for it flashed across her mind that she had
#
# IV Line is: never before seen a rabbit with either a waistcoat-pocket, or a watch
#
# IV Line is: to take out of it, and burning with curiosity, she ran across the field
#
# IV Line is: after it, and fortunately was just in time to see it pop down a large
#
# IV Line is: rabbit-hole under the hedge.
# Type f is: <class '_io.TextIOWrapper'>
# V Line is: ï»¿Title: Alice's Adventures in Wonderland
#
# V Line is:
#
# V Line is: Author: Lewis Carroll
#
# V Line is:
#
# V Line is: Posting Date: June 25, 2008 [EBook #11]
#
# V Line is: Release Date: March, 1994
#
# V Line is: [Last updated: December 20, 2011]
#
# V Line is:
#
# V Line is: Language: English
#
# V Line is:
#
# V Line is:
#
# V Line is: CHAPTER I. Down the Rabbit-Hole
#
# V Line is:
#
# V Line is: Alice was beginning to get very tired of sitting by her sister on the
#
# V Line is: bank, and of having nothing to do: once or twice she had peeped into the
#
# V Line is: book her sister was reading, but it had no pictures or conversations in
#
# V Line is: it, 'and what is the use of a book,' thought Alice 'without pictures or
#
# V Line is: conversations?'
#
# V Line is:
#
# V Line is: So she was considering in her own mind (as well as she could, for the
#
# V Line is: hot day made her feel very sleepy and stupid), whether the pleasure
#
# V Line is: of making a daisy-chain would be worth the trouble of getting up and
#
# V Line is: picking the daisies, when suddenly a White Rabbit with pink eyes ran
#
# V Line is: close by her.
#
# V Line is:
#
# V Line is: There was nothing so VERY remarkable in that; nor did Alice think it so
#
# V Line is: VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
#
# V Line is: Oh dear! I shall be late!' (when she thought it over afterwards, it
#
# V Line is: occurred to her that she ought to have wondered at this, but at the time
#
# V Line is: it all seemed quite natural); but when the Rabbit actually TOOK A WATCH
#
# V Line is: OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,
#
# V Line is: Alice started to her feet, for it flashed across her mind that she had
#
# V Line is: never before seen a rabbit with either a waistcoat-pocket, or a watch
#
# V Line is: to take out of it, and burning with curiosity, she ran across the field
#
# V Line is: after it, and fortunately was just in time to see it pop down a large
#
# V Line is: rabbit-hole under the hedge.

# %%
# FILE I/O
#
#
# Read by chars
#
try:
    f = open('data/VanLinkedIn18-12-2018.txt', mode = 'rt', encoding = 'utf-8')
    txt = f.read(90)
    print('I First 90 chars: {}'.format(txt))
    print('I File position: {}'.format(f.tell()))
    print('I Cursor to initial position: {}'.format(f.seek(0)))
    txt = f.read(90)
    print('I File content after first having read 90 chars: {}'.format(f.read()))
finally:
    f.close()
#
# read by line (see also FOR loop in files-readTxt-1.py)
#
try:
    f = open('data/VanLinkedIn18-12-2018.txt', mode = 'rt', encoding = 'utf-8')
    print('II File is readable: {}'.format(f.readable()))
    print('II Line is {}'.format(f.readline()))
    print('II Line is {}'.format(f.readline()))
    print('II Line is {}'.format(f.readline()))
    print('II Line is {}'.format(f.readline()))
    print('II Line is {}'.format(f.readlines())) # returns line in list []
finally:
    f.close()
# Out:
# I Eerste 90 chars: Given:
#
# 11 x 11 = 4
# 22 x 22 = 16
# 33 x 33 = ?
#
# This puzzle/riddle is not new; several dated
# I File position: 96
# I Cursor to initial position: 0
# I File content after first having read 90 chars:  YouTube films are decicated to it.
# See also:
#
# of course 11 x 11 = 121 as 22 x 22 = 484 and 33 x 33 = 1089.
#
# So what do the given answers tell us?
# 16, being the square of 4,
#
# Approach 1: power 2 of sum of the 2 digits in the number
# 11 x 11 = 121. 11^2 seen as 2^2 => 4
# 22 x 22 = 484. 22^2 seen as 4^2 => 16
# 33 x 33 = 1089. 33^2 seen as 6^2 => 36
# 44 x 44 = 1936. 44^2 seen as 8^2 => 64
# 55 x 55 = 3025. 55^2 seen as 10^2 => 100
# 66 x 66 = 4356. 66^2 seen as 12^2 => 144
# 77 x 77 = 5929. 77^2 seen as 14^2 => 196
# 88 x 88 = 7744. 88^2 seen as 16^2 => 256
#
# Approach 2 Number Series to check if there is consistency in the above answers.
# 4	16	36	64	100	144	196	256	?
#      12      20      28     36       44      52     60
# As you can see each time 8 is added to the previous difference to get the next answer.
# So the question mark should be 256 + 60+8 = 324 and that is exactly 99 x 99 = 9801 or 99^2 and seen as 18^2 gives 324.
#
# Approach 3 Cross multiplication
# 121 x 16 <=> 484 x 4 = 1936 (* 9 gives 17424 ) (36 / 4 = 9)
# 484 x 36 <=> 1089 x 16 = 17424 (* 4 gives 69696) (64 / 16 = 4)
# 1089 x 64 <=> 1936 x 36 = 69696 (* 2,7777777777 gives 193600) (100 / 26 = 2,7777777)
# 1936 x 100 <=> 3025 x 64 = 193600 (* 2,25 gives 435600) (144 / 64 = 2,25)
# 3025 x 144 <=> 4356 x 100 = 435600 (* 1,96 gives 853776) (196 / 144 = 1,96)
# 4356 x 196 <=> 5929 x 144 = 853776
# and so on
#
# Approach 4
# 4 x 121 = 484 (22^2)
# 4 x 484 = 1936 (44^2)
# 4 x 1089 = 4356 (66^2)
# 4 x 1936 = 7744 (88^2)
# and so on
#
# Gevonden ergens op internet:
# Beschouw x als variabele zodat er staat: 11 * x * 11 = 4
# <=> x = 4 / 121
# Dit geldt ook voor 22 * x * 22 = 16 => x = 16/484 = 4/121
# Daaruit volgt dat 33 * 4/121 * 33 = 36
#
# II File is readable: True
# II Line is Given:
#
# II Line is
#
# II Line is 11 x 11 = 4
#
# II Line is 22 x 22 = 16
#
# II Line is ['33 x 33 = ?\n', '\n', 'This puzzle/riddle is not new; several dated YouTube films are decicated to it.\n', 'See also: \n', '\n', 'of course 11 x 11 = 121 as 22 x 22 = 484 and 33 x 33 = 1089.\n', '\n', 'So what do the given answers tell us?\n', '16, being the square of 4, \n', '\n', 'Approach 1: power 2 of sum of the 2 digits in the number\n', '11 x 11 = 121. 11^2 seen as 2^2 => 4\n', '22 x 22 = 484. 22^2 seen as 4^2 => 16\n', '33 x 33 = 1089. 33^2 seen as 6^2 => 36\n', '44 x 44 = 1936. 44^2 seen as 8^2 => 64\n', '55 x 55 = 3025. 55^2 seen as 10^2 => 100\n', '66 x 66 = 4356. 66^2 seen as 12^2 => 144\n', '77 x 77 = 5929. 77^2 seen as 14^2 => 196\n', '88 x 88 = 7744. 88^2 seen as 16^2 => 256\n', '\n', 'Approach 2 Number Series to check if there is consistency in the above answers.\n', '4\t16\t36\t64\t100\t144\t196\t256\t?\n', '     12      20      28     36       44      52     60\n', 'As you can see each time 8 is added to the previous difference to get the next answer.\n', 'So the question mark should be 256 + 60+8 = 324 and that is exactly 99 x 99 = 9801 or 99^2 and seen as 18^2 gives 324.\n', '\n', 'Approach 3 Cross multiplication\n', '121 x 16 <=> 484 x 4 = 1936 (* 9 gives 17424 ) (36 / 4 = 9)\n', '484 x 36 <=> 1089 x 16 = 17424 (* 4 gives 69696) (64 / 16 = 4)\n', '1089 x 64 <=> 1936 x 36 = 69696 (* 2,7777777777 gives 193600) (100 / 26 = 2,7777777)\n', '1936 x 100 <=> 3025 x 64 = 193600 (* 2,25 gives 435600) (144 / 64 = 2,25)\n', '3025 x 144 <=> 4356 x 100 = 435600 (* 1,96 gives 853776) (196 / 144 = 1,96)\n', '4356 x 196 <=> 5929 x 144 = 853776\n', 'and so on\n', '\n', 'Approach 4 \n', '4 x 121 = 484 (22^2)\n', '4 x 484 = 1936 (44^2)\n', '4 x 1089 = 4356 (66^2)\n', '4 x 1936 = 7744 (88^2)\n', 'and so on\n', '\n', 'Gevonden ergens op internet:\n', 'Beschouw x als variabele zodat er staat: 11 * x * 11 = 4\n', '<=> x = 4 / 121\n', 'Dit geldt ook voor 22 * x * 22 = 16 => x = 16/484 = 4/121\n', 'Daaruit volgt dat 33 * 4/121 * 33 = 36\n']

# %% [markdown]
# ## Writing text file
# The code presented below reads from one file and writes the contents to a newly opened file. So actually a copy action. Two methods are compared in terms of computing time: using a FOR loop and using `readlines()` to get a LIST. That's why the `time` module is imported.

# %%
# FILE I/O - write to file
#
import os, time
#
# read line from file and write to other file
#
try:
    if os.path.exists('data/WrittenCopyOfFile'):
        os.remove('data/WrittenCopyOfFile')
    f = open('data/VanLinkedIn18-12-2018.txt')
    start = time.time()
    g = open('data/WrittenCopyOfFile', 'w')
    for line in f:
        g.write(line)
    end = time.time()
    print('I Time consumed using FOR loop: {}'.format(end - start))
finally:
    g.close()
    f.close()

#
# alternative copying lines to a new file
#
try:
    os.remove(r'data/WrittenCopyOfFile')
    f = open('data/VanLinkedIn18-12-2018.txt')
    start = time.time()
    g = open('data/WrittenCopyOfFile', 'w')
    fileContentsInList = f.readlines()
    g.writelines(fileContentsInList)
    end = time.time()
    print('II Time consumed using LIST: {}'.format(end - start))
finally:
    g.close()
    f.close()
# Out:
# I Time consumed using FOR loop: 0.0
# II Time consumed using LIST: 0.0

# %% [markdown]
# ## Writing binary file
# This is essentially not different from reading/writing text files. However the mode argument must indicate that we're dealing with binary files.

# %%
# FILE I/O - write to file
#
import os, time
#
# read line from file and write to other file
#
try:
    if os.path.exists('data/WrittenCopyOfBinFile.jpg'):
        os.remove('data/WrittenCopyOfBinFile.jpg')
    f = open('data/NocturnesTitleCraeijvanger.jpg', 'rb') # mode rb > read binary
    start = time.time()
    g = open('data/WrittenCopyOfBinFile.jpg', 'wb') # mode wb > write binary
    for line in f:
        g.write(line)
    end = time.time()
    print('I Time consumed using FOR loop: {}'.format(end - start))
finally:
    g.close()
    f.close()
# Out:
# I Time consumed using FOR loop: 0.0
